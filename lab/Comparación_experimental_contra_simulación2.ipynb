# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16.0, 5.0)

from funcions_lab import lab, plot_lab

# %% [markdown]
# Los valores que se usaran sacados del paper:

# %%
aceptor2 = [0, 20, 60, 120, 240, 600, 1000]
eff2 = [0, 0.42, 0.58, 0.85, 0.92, 0.97, 0.98]

r = 15 # nm
tau_D = 0.333 # ns
R_Forster = 3.05 # nm

L_DS = [4, 8] # nm
num_exc = 1500

# %% [markdown]
# Se corre el codigo:

# %%
epsilon = 0.05

resultado2a = lab(r, R_Forster, L_DS, tau_D, epsilon, num_exc, aceptor2)
print("-------------------")
print(resultado2a)
# Out:
# L_D de  4 nm. Numero de aceptores: 0 , 20
#  , 60
#  , 120
#  , 240
#  , 600
#  , 1000
#  ,
# L_D de  8 nm. Numero de aceptores: 0 , 20
#  , 60
#  , 120
#  , 240
#  , 600
#  , 1000
#  ,
# -------------------
# [[0.0, 0.56, 0.7133333333333334, 0.8366666666666667, 0.8946666666666667, 0.9173333333333333, 0.9493333333333334], 4, [0.0, 0.6273333333333333, 0.8073333333333333, 0.882, 0.9266666666666666, 0.964, 0.9686666666666667], 8]
# ../src/exciton.py:71: RuntimeWarning: overflow encountered in double_scalars
#   prob = 1 - e**(self.NP.delta_t * cte*sum(dist))

# %%
epsilon = 0.1

resultado2b = lab(r, R_Forster, L_DS, tau_D, epsilon, num_exc, aceptor2)
print("-------------------")
print(resultado2b)
# Out:
# L_D de  4 nm. Numero de aceptores: 0 , 20
#  , 60
#  , 120
#  , 240
#  , 600
#  , 1000
#  ,
# L_D de  8 nm. Numero de aceptores: 0 , 20
#  , 60
#  , 120
#  , 240
#  , 600
#  , 1000
#  ,
# -------------------
# [[0.0, 0.6026666666666667, 0.7826666666666666, 0.8366666666666667, 0.884, 0.918, 0.9273333333333333], 4, [0.0, 0.6586666666666666, 0.808, 0.8946666666666667, 0.9233333333333333, 0.9526666666666667, 0.9533333333333334], 8]

# %%
epsilon = 0.5

resultado2c = lab(r, R_Forster, L_DS, tau_D, epsilon, num_exc, aceptor2)
print("-------------------")
print(resultado2c)
# Out:
# L_D de  4 nm. Numero de aceptores: 0 , 20
#  , 60
#  , 120
#  , 240
#  , 600
#  , 1000
#  ,
# L_D de  8 nm. Numero de aceptores: 0 , 20
#  , 60
#  , 120
#  , 240
#  , 600
#  , 1000
#  ,
# -------------------
# [[0.0, 0.582, 0.6613333333333333, 0.74, 0.7446666666666667, 0.752, 0.7666666666666667], 4, [0.0, 0.6613333333333333, 0.8013333333333333, 0.8253333333333334, 0.8573333333333333, 0.8626666666666667, 0.876], 8]

# %%
epsilon = 1

resultado2d = lab(r, R_Forster, L_DS, tau_D, epsilon, num_exc, aceptor2)
print("-------------------")
print(resultado2d)
# Out:
# L_D de  4 nm. Numero de aceptores: 0 , 20
#  , 60
#  , 120
#  , 240
#  , 600
#  , 1000
#  ,
# L_D de  8 nm. Numero de aceptores: 0 , 20
#  , 60
#  , 120
#  , 240
#  , 600
#  , 1000
#  ,
# -------------------
# [[0.0, 0.5053333333333333, 0.588, 0.5893333333333334, 0.602, 0.63, 0.6226666666666667], 4, [0.0, 0.6333333333333333, 0.7253333333333334, 0.7253333333333334, 0.7493333333333333, 0.76, 0.7513333333333333], 8]

# %%
resultado2a = [[0.0, 0.56, 0.7133333333333334, 0.8366666666666667, 0.8946666666666667, 0.9173333333333333, 0.9493333333333334], 4,
               [0.0, 0.6273333333333333, 0.8073333333333333, 0.882, 0.9266666666666666, 0.964, 0.9686666666666667], 8]
resultado2b = [[0.0, 0.6026666666666667, 0.7826666666666666, 0.8366666666666667, 0.884, 0.918, 0.9273333333333333], 4,
               [0.0, 0.6586666666666666, 0.808, 0.8946666666666667, 0.9233333333333333, 0.9526666666666667, 0.9533333333333334], 8]
resultado2c = [[0.0, 0.582, 0.6613333333333333, 0.74, 0.7446666666666667, 0.752, 0.7666666666666667], 4,
               [0.0, 0.6613333333333333, 0.8013333333333333, 0.8253333333333334, 0.8573333333333333, 0.8626666666666667, 0.876], 8]
resultado2d = [[0.0, 0.5053333333333333, 0.588, 0.5893333333333334, 0.602, 0.63, 0.6226666666666667], 4,
               [0.0, 0.6333333333333333, 0.7253333333333334, 0.7253333333333334, 0.7493333333333333, 0.76, 0.7513333333333333], 8,
               [0.0, 0.7853333333333333, 0.872, 0.91, 0.9153333333333333, 0.944, 0.948], 20]

# %% [markdown]
# Se grafican los resultados para diferentes epsilon:

# %%
plot_lab(resultado2a, aceptor2, eff2, '2do dopante para epsilon = 0.05')
plot_lab(resultado2b, aceptor2, eff2, '2do dopante para epsilon = 0.1')
plot_lab(resultado2c, aceptor2, eff2, '2do dopante para epsilon = 0.5')
plot_lab(resultado2d, aceptor2, eff2, '2do dopante para epsilon = 1')

# %% [markdown]
# Se corre el codigo para un radio de 30 nm

# %%
num_exc = 1500
epsilon = 0.05
r = 30
resultado2c = lab(r, R_Forster, [4, 8, 12, 16, 20],, tau_D, epsilon, num_exc, aceptor2)
print("-------------------")
print(resultado2c)
plot_lab(resultado2c)

# %%
resultado2a_r30 = [[0.0, 0.32466666666666666, 0.5593333333333333, 0.6986666666666667, 0.8006666666666666, 0.8853333333333333, 0.9153333333333333], 4,
                   [0.0, 0.352, 0.592, 0.74, 0.838, 0.9113333333333333, 0.944], 8,
                   [0.0, 0.344, 0.6413333333333333, 0.788, 0.866, 0.928, 0.9586666666666667], 12,
                   [0.0, 0.382, 0.632, 0.768, 0.8773333333333333, 0.9473333333333334, 0.9566666666666667], 16,
                   [0.0, 0.39266666666666666, 0.6873333333333334, 0.7866666666666666, 0.898, 0.9573333333333334, 0.9733333333333334], 20]
plot_lab(resultado2a_r30, aceptor2, eff2, '2er dopante para epsilon = 0.05, pero con r = 30')

# %%
epsilon = 0.5

resultado2f = lab(r, R_Forster, [20], tau_D, epsilon, num_exc, aceptor2)
print("-------------------")
print(resultado2f)
# Out:
# L_D de  20 nm. Numero de aceptores: 0 , 20
#  , 60
#  , 120
#  , 240
#  , 600
#  , 1000
#  ,
# -------------------
# [[0.0, 0.7853333333333333, 0.872, 0.91, 0.9153333333333333, 0.944, 0.948], 20]
# ../src/exciton.py:71: RuntimeWarning: overflow encountered in double_scalars
#   prob = 1 - e**(self.NP.delta_t * cte*sum(dist))

# %%
epsilon = 1

resultado2f = lab(r, R_Forster, [40, 50, 60, 70, 80], tau_D, epsilon, num_exc, aceptor2)
print("-------------------")
print(resultado2f)
# Out:
# L_D de  40 nm. Numero de aceptores: 0 , 20
#  , 60
#  , 120
#  , 240
#  , 600
#  , 1000
#  ,
# L_D de  50 nm. Numero de aceptores: 0 , 20
#  , 60
#  , 120
#  , 240
#  , 600
#  , 1000
#  ,
# L_D de  60 nm. Numero de aceptores: 0 , 20
#  , 60
#  , 120
#  , 240
#  , 600
#  , 1000
#  ,
# L_D de  70 nm. Numero de aceptores: 0 , 20
#  , 60
#  , 120
#  , 240
#  , 600
#  , 1000
#  ,
# L_D de  80 nm. Numero de aceptores: 0 , 20
#  , 60
#  , 120
#  , 240
#  , 600
#  , 1000
#  ,
# -------------------
# ...

# %%
plot_lab(resultado2f, aceptor2, eff2, '2er dopante para epsilon = 1')
