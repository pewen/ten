# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16.0, 5.0)

from funcions_lab import lab, plot_lab

# %% [markdown]
# Los valores que se usaran sacados del paper:

# %%
aceptor1 = [0, 21, 43, 86, 171, 436, 871]
eff1 = [0, 0.1875, 0.3125, 0.68, 0.78, 0.9, 0.95]
R_Forster = 2.29
r = 15 
tau_D = 0.333

L_DS = [4, 8]
num_exc = 1500

# %% [markdown]
# Se corre el codigo:

# %%
epsilon = 0.05

resultado1a = lab(r, R_Forster, L_DS, tau_D, epsilon, num_exc, aceptor1)
print("-------------------")
print(resultado1a)
# Out:
# L_D de  4 nm. Numero de aceptores: 0 , 21
#  , 43
#  , 86
#  , 171
#  , 436
#  , 871
#  ,
# L_D de  8 nm. Numero de aceptores: 0 , 21
#  , 43
#  , 86
#  , 171
#  , 436
#  , 871
#  ,
# -------------------
# [[0.0, 0.4066666666666667, 0.5786666666666667, 0.7006666666666667, 0.8066666666666666, 0.908, 0.9293333333333333], 4, [0.0, 0.4673333333333333, 0.652, 0.7806666666666666, 0.862, 0.9266666666666666, 0.9526666666666667], 8]
# ../src/exciton.py:71: RuntimeWarning: overflow encountered in double_scalars
#   prob = 1 - e**(self.NP.delta_t * cte*sum(dist))

# %%
epsilon = 0.1

resultado1b = lab(r, R_Forster, L_DS, tau_D, epsilon, num_exc, aceptor1)
print("-------------------")
print(resultado1b)
# Out:
# L_D de  4 nm. Numero de aceptores: 0 , 21
#  , 43
#  , 86
#  , 171
#  , 436
#  , 871
#  ,
# L_D de  8 nm. Numero de aceptores: 0 , 21
#  , 43
#  , 86
#  , 171
#  , 436
#  , 871
#  ,
# -------------------
# [[0.0, 0.462, 0.6266666666666667, 0.73, 0.8086666666666666, 0.8846666666666667, 0.9073333333333333], 4, [0.0, 0.5053333333333333, 0.6826666666666666, 0.8106666666666666, 0.8786666666666667, 0.9266666666666666, 0.9493333333333334], 8]

# %%
epsilon = 0.5

resultado1c = lab(r, R_Forster, L_DS, tau_D, epsilon, num_exc, aceptor1)
print("-------------------")
print(resultado1c)
# Out:
# L_D de  4 nm. Numero de aceptores: 0 , 21
#  , 43
#  , 86
#  , 171
#  , 436
#  , 871
#  ,
# L_D de  8 nm. Numero de aceptores: 0 , 21
#  , 43
#  , 86
#  , 171
#  , 436
#  , 871
#  ,
# -------------------
# [[0.0, 0.44, 0.57, 0.656, 0.7286666666666667, 0.75, 0.7653333333333333], 4, [0.0, 0.5346666666666666, 0.6786666666666666, 0.752, 0.814, 0.8526666666666667, 0.8713333333333333], 8]

# %%
epsilon = 1

resultado1d = lab(r, R_Forster, L_DS, tau_D, epsilon, num_exc, aceptor1)
print("-------------------")
print(resultado1d)
# Out:
# L_D de  4 nm. Numero de aceptores: 0 , 21
#  , 43
#  , 86
#  , 171
#  , 436
#  , 871
#  ,
# L_D de  8 nm. Numero de aceptores: 0 , 21
#  , 43
#  , 86
#  , 171
#  , 436
#  , 871
#  ,
# -------------------
# [[0.0, 0.3873333333333333, 0.48533333333333334, 0.5566666666666666, 0.5926666666666667, 0.62, 0.622], 4, [0.0, 0.4726666666666667, 0.578, 0.69, 0.732, 0.77, 0.7613333333333333], 8]

# %%
resultado1a = [[0.0, 0.4066666666666667, 0.5786666666666667, 0.7006666666666667, 0.8066666666666666, 0.908, 0.9293333333333333], 4,
               [0.0, 0.4673333333333333, 0.652, 0.7806666666666666, 0.862, 0.9266666666666666, 0.9526666666666667], 8]
resultado1b = [[0.0, 0.462, 0.6266666666666667, 0.73, 0.8086666666666666, 0.8846666666666667, 0.9073333333333333], 4,
               [0.0, 0.5053333333333333, 0.6826666666666666, 0.8106666666666666, 0.8786666666666667, 0.9266666666666666, 0.9493333333333334], 8]
resultado1c = [[0.0, 0.44, 0.57, 0.656, 0.7286666666666667, 0.75, 0.7653333333333333], 4,
               [0.0, 0.5346666666666666, 0.6786666666666666, 0.752, 0.814, 0.8526666666666667, 0.8713333333333333], 8]
resultado1d = [[0.0, 0.3873333333333333, 0.48533333333333334, 0.5566666666666666, 0.5926666666666667, 0.62, 0.622], 4,
               [0.0, 0.4726666666666667, 0.578, 0.69, 0.732, 0.77, 0.7613333333333333], 8]

# %% [markdown]
# Se grafican los resultados para diferentes epsilon:

# %%
plot_lab(resultado1a, aceptor1, eff1, '1er dopante para epsilon = 0.05')
plot_lab(resultado1b, aceptor1, eff1, '1er dopante para epsilon = 0.1')
plot_lab(resultado1c, aceptor1, eff1, '1er dopante para epsilon = 0.5')
plot_lab(resultado1d, aceptor1, eff1, '1er dopante para epsilon = 1')

# %% [markdown]
# Se corre el codigo para un radio de 30 nm

# %%
epsilon = 0.05
r = 30
resultado1a_r30 = lab(r, R_Forster, [4, 8, 12, 16], tau_D, epsilon, num_exc, aceptor1)
print("-------------------")
print(resultado1a)
plot_lab(resultado1a_r30, aceptor1, eff1, '1er dopante para epsilon = 0.05, pero con r = 30')
# Out:
# L_D de  4 nm. Numero de aceptores: 0 , 21
#  , 43
#  , 86
#  , 171
#  , 436
#  , 871
#  ,
# L_D de  8 nm. Numero de aceptores: 0 , 21
#  , 43
#  , 86
#  , 171
#  , 436
#  , 871
#  ,
# L_D de  12 nm. Numero de aceptores: 0 , 21
#  , 43
#  , 86
#  , 171
#  , 436
#  , 871
#  ,
# L_D de  16 nm. Numero de aceptores: 0 , 21
#  , 43
#  , 86
#  , 171
#  , 436
#  , 871
#  ,
# -------------------
# [[0.0, 0.4066666666666667, 0.5786666666666667, 0.7006666666666667, 0.8066666666666666, 0.908, 0.9293333333333333], 4, [0.0, 0.4673333333333333, 0.652, 0.7806666666666666, 0.862, 0.9266666666666666, 0.9526666666666667], 8]
