# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16.0, 5.0)

from funcions_lab import lab, plot_lab

# %% [markdown]
# Los valores que se usaran sacados del paper:

# %%
aceptor3 = [0, 40, 100, 200, 400, 1000]
eff3 = [0, 0.48, 0.82, 0.9, 0.95, 0.98]
R_Forster = 3.14
r = 15 
tau_D = 0.333

L_DS = [4, 8]
num_exc = 1500

# %% [markdown]
# Se corre el codigo:

# %%
epsilon = 0.05

resultado3a = lab(r, R_Forster, L_DS, tau_D, epsilon, num_exc, aceptor3)
print("-------------------")
print(resultado3a)
# Out:
# L_D de  4 nm. Numero de aceptores: 0 , 40
#  , 100
#  , 200
#  , 400
#  , 1000
#  ,
# L_D de  8 nm. Numero de aceptores: 0 , 40
#  , 100
#  , 200
#  , 400
#  , 1000
#  ,
# -------------------
# [[0.0, 0.7086666666666667, 0.8226666666666667, 0.872, 0.904, 0.9493333333333334], 4, [0.0, 0.7393333333333333, 0.8513333333333334, 0.9126666666666666, 0.9466666666666667, 0.9653333333333334], 8]
# ../src/exciton.py:71: RuntimeWarning: overflow encountered in double_scalars
#   prob = 1 - e**(self.NP.delta_t * cte*sum(dist))

# %%
epsilon = 0.1

resultado3b = lab(r, R_Forster, L_DS, tau_D, epsilon, num_exc, aceptor3)
print("-------------------")
print(resultado3b)
# Out:
# L_D de  4 nm. Numero de aceptores: 0 , 40
#  , 100
#  , 200
#  , 400
#  , 1000
#  ,
# L_D de  8 nm. Numero de aceptores: 0 , 40
#  , 100
#  , 200
#  , 400
#  , 1000
#  ,
# -------------------
# [[0.0, 0.716, 0.8213333333333334, 0.88, 0.904, 0.9273333333333333], 4, [0.0, 0.758, 0.8873333333333333, 0.9206666666666666, 0.9373333333333334, 0.9606666666666667], 8]

# %%
epsilon = 0.5

resultado3c = lab(r, R_Forster, L_DS, tau_D, epsilon, num_exc, aceptor3)
print("-------------------")
print(resultado3c)
# Out:
# L_D de  4 nm. Numero de aceptores: 0 , 40
#  , 100
#  , 200
#  , 400
#  , 1000
#  ,
# L_D de  8 nm. Numero de aceptores: 0 , 40
#  , 100
#  , 200
#  , 400
#  , 1000
#  ,
# -------------------
# [[0.0, 0.6393333333333333, 0.726, 0.7213333333333334, 0.7413333333333333, 0.7613333333333333], 4, [0.0, 0.77, 0.83, 0.862, 0.8566666666666667, 0.878], 8]

# %%
epsilon = 1

resultado3d = lab(r, R_Forster, L_DS, tau_D, epsilon, num_exc, aceptor3)
print("-------------------")
print(resultado3d)
# Out:
# L_D de  4 nm. Numero de aceptores: 0 , 40
#  , 100
#  , 200
#  , 400
#  , 1000
#  ,
# L_D de  8 nm. Numero de aceptores: 0 , 40
#  , 100
#  , 200
#  , 400
#  , 1000
#  ,
# -------------------
# [[0.0, 0.5746666666666667, 0.5993333333333334, 0.604, 0.6053333333333333, 0.6186666666666667], 4, [0.0, 0.6913333333333334, 0.7453333333333333, 0.7493333333333333, 0.7686666666666667, 0.7806666666666666], 8]

# %%
resultado3a = [[0.0, 0.7086666666666667, 0.8226666666666667, 0.872, 0.904, 0.9493333333333334], 4,
               [0.0, 0.7393333333333333, 0.8513333333333334, 0.9126666666666666, 0.9466666666666667, 0.9653333333333334], 8]
resultado3b = [[0.0, 0.716, 0.8213333333333334, 0.88, 0.904, 0.9273333333333333], 4,
               [0.0, 0.758, 0.8873333333333333, 0.9206666666666666, 0.9373333333333334, 0.9606666666666667], 8]
resultado3c = [[0.0, 0.6393333333333333, 0.726, 0.7213333333333334, 0.7413333333333333, 0.7613333333333333], 4,
               [0.0, 0.77, 0.83, 0.862, 0.8566666666666667, 0.878], 8]
resultado3d = [[0.0, 0.5746666666666667, 0.5993333333333334, 0.604, 0.6053333333333333, 0.6186666666666667], 4,
               [0.0, 0.6913333333333334, 0.7453333333333333, 0.7493333333333333, 0.7686666666666667, 0.7806666666666666], 8]

# %% [markdown]
# Se grafican los resultados para diferentes epsilon:

# %%
plot_lab(resultado3a, aceptor3, eff3, '3er dopante para epsilon = 0.05')
plot_lab(resultado3b, aceptor3, eff3, '3er dopante para epsilon = 0.1')
plot_lab(resultado3c, aceptor3, eff3, '3er dopante para epsilon = 0.5')
plot_lab(resultado3d, aceptor3, eff3, '3er dopante para epsilon = 1')

# %% [markdown]
# Se corre el codigo para un radio de 30 nm

# %%
epsilon = 0.05
r = 30
resultado3a_r30 = lab(r, R_Forster, [4, 8, 12, 16], tau_D, epsilon, num_exc, aceptor3)
print("-------------------")
print(resultado3a_r30)
# Out:
# L_D de  4 nm. Numero de aceptores: 0 , 40
#  , 100
#  , 200
#  , 400
#  , 1000
#  ,
# L_D de  8 nm. Numero de aceptores: 0 , 40
#  , 100
#  , 200
#  , 400
#  , 1000
#  ,
# L_D de  12 nm. Numero de aceptores: 0 , 40
#  , 100
#  , 200
#  , 400
#  , 1000
#  ,
# L_D de  16 nm. Numero de aceptores: 0 , 40
#  , 100
#  , 200
#  , 400
#  , 1000
#  ,
# -------------------
# [[0.0, 0.5106666666666667, 0.666, 0.7726666666666666, 0.858, 0.9213333333333333], 4, [0.0, 0.5246666666666666, 0.7093333333333334, 0.8246666666666667, 0.894, 0.9546666666666667], 8, [0.0, 0.548, 0.73, 0.8586666666666667, 0.918, 0.9513333333333334], 12, [0.0, 0.5473333333333333, 0.7626666666666667, 0.8846666666666667, 0.9386666666666666, 0.9666666666666667], 16]
# ../src/exciton.py:71: RuntimeWarning: overflow encountered in double_scalars
#   prob = 1 - e**(self.NP.delta_t * cte*sum(dist))

# %%
resultado3a_r30= [[0.0, 0.5106666666666667, 0.666, 0.7726666666666666, 0.858, 0.9213333333333333], 4,
                  [0.0, 0.5246666666666666, 0.7093333333333334, 0.8246666666666667, 0.894, 0.9546666666666667], 8,
                  [0.0, 0.548, 0.73, 0.8586666666666667, 0.918, 0.9513333333333334], 12,
                  [0.0, 0.5473333333333333, 0.7626666666666667, 0.8846666666666667, 0.9386666666666666, 0.9666666666666667], 16]
plot_lab(resultado3a_r30, aceptor3, eff3, '3er dopante para epsilon = 0.05, pero con r = 30')
