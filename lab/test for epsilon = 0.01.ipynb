# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16.0, 5.0)

from funcions_lab import *

# %%
aceptor1 = [0, 21, 43, 86, 171, 436, 871]
eff1 = [0, 0.1875, 0.3125, 0.68, 0.78, 0.9, 0.95]
R_Forster = 2.29
r = 15 
tau_D = 0.333

L_DS = [4, 8, 12]
num_exc = 1000

# %%
epsilon = 0.01

resultado1a = lab(r, R_Forster, L_DS, tau_D, epsilon, num_exc, aceptor1)
print("-------------------")
print(resultado1a)

# %%
resultado1a = [[0.0, 0.426, 0.498, 0.648, 0.774, 0.89, 0.952], 4, [0.0, 0.348, 0.44, 0.634, 0.712, 0.874, 0.936], 8]

# %%
aceptor2 = [0, 20, 60, 120, 240, 600, 1000]
eff2 = [0, 0.42, 0.58, 0.85, 0.92, 0.97, 0.98]

r = 15 # nm
tau_D = 0.333 # ns
R_Forster = 3.05 # nm

L_DS = [4, 8] # nm
num_exc = 1500

# %%
epsilon = 0.01

resultado2a = lab(r, R_Forster, L_DS, tau_D, epsilon, num_exc, aceptor2)
print("-------------------")
print(resultado2a)
# Out:
# L_D de  4 nm. Numero de aceptores: 0 , 20
#  , 60
#  , 120
#  , 240
#  , 600
#  , 1000
#  ,
# L_D de  8 nm. Numero de aceptores: 0 , 20
#  , 60
#  , 120
#  , 240
#  , 600
#  , 1000
#  ,
# -------------------
# [[0.0, 0.5113333333333333, 0.6866666666666666, 0.78, 0.8533333333333334, 0.94, 0.9606666666666667], 4, [0.0, 0.5393333333333333, 0.6953333333333334, 0.8113333333333334, 0.898, 0.968, 0.9786666666666667], 8]
# ../src/exciton.py:71: RuntimeWarning: overflow encountered in double_scalars
#   prob = 1 - e**(self.NP.delta_t * cte*sum(dist))

# %%
resultado2a = [[0.0, 0.5113333333333333, 0.6866666666666666, 0.78, 0.8533333333333334, 0.94, 0.9606666666666667], 4, [0.0, 0.5393333333333333, 0.6953333333333334, 0.8113333333333334, 0.898, 0.968, 0.9786666666666667], 8]

# %%
# Para al 3ra
aceptor3 = [0, 40, 100, 200, 400, 1000]
eff3 = [0, 0.48, 0.82, 0.9, 0.95, 0.98]
R_Forster = 3.14
r = 15 
tau_D = 0.333

L_DS = [4, 8]
num_exc = 1000

# %%
epsilon = 0.01

resultado3a = lab(r, R_Forster, L_DS, tau_D, epsilon, num_exc, aceptor3)
print("-------------------")
print(resultado3a)

# %%
resultado3a = [[0.0, 0.564, 0.736, 0.824, 0.92, 0.969], 4, [0.0, 0.659, 0.801, 0.87, 0.945, 0.976], 8]

# %%
plot_lab(resultado1a, aceptor1, eff1, '1er dopante para epsilon = 0.01')
plot_lab(resultado2a, aceptor2, eff2, '2er dopante para epsilon = 0.01')
plot_lab(resultado3a, aceptor3, eff3, '3er dopante para epsilon = 0.01')
