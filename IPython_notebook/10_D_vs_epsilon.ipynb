# %% [markdown]
# # Variando $D$ y $\epsilon$
#
# De los parámetros iniciales, vamos a varian unicamnete estos dos debido a que son complicados para medir, lo que hace que tengan un gran error.
#
# Nuestra idea es, realizar varias simulaciones variando estos parámetros, calcular la distancia cuadratica entre los valos obtenidos y los valores experimentales del paper de Mc Neal y ver como varia esta distancia.

# %%
import os
import sys
sys.path.append('../')

import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib.pyplot as plt
#%matplotlib inline

import ten

# %% [markdown]
# Datos del paper de Mc. Neal.

# %%
# Datos del paper de McNeal

# Perylene:
aceptor_perylene = [0, 21, 43, 86, 171, 436, 871]
eff_perylene = [0, 0.1875, 0.3125, 0.68, 0.78, 0.9, 0.95]

# Coumarin 6
aceptor_coumarin = [0, 20, 60, 120, 240, 600, 1000]
eff_coumarin = [0, 0.42, 0.58, 0.85, 0.92, 0.97, 0.98]

# TPP
aceptor_TPP = [0, 40, 100, 200, 400, 1000]
eff_TPP = [0, 0.48, 0.82, 0.9, 0.95, 0.98]

# %%
# TPP 
data = ten.post.extrac4dir('data/TPP/', aceptor_TPP)
data = ten.post.diference2(eff_TPP, data)

# 3D plot
x = data[:,0]
y = data[:,1]
z = data[:,3]

fig = plt.figure(figsize=(12, 8))
ax = fig.gca(projection='3d')
surf = ax.plot_trisurf(x, y, z, cmap=cm.jet, linewidth=0.2)
ax.set_xlabel(r'$Mean\; Free\; Path\; (D)$', fontsize=20)
ax.set_ylabel(r'$\epsilon$', fontsize=20)
ax.set_zlabel(r'$Squared\; Difference$', fontsize=20)
fig.colorbar(surf, shrink=0.5, aspect=10)
plt.show()

# %%
cont = []
x_new = []
y_new = []
z_new = []

for i in range(len(y)):
    if y[i] == 1:
        cont.append(i)
        x_new.append(x[i])
        y_new.append(y[i])
        z_new.append(z[i])

        
plt.plot(x_new, z_new, 'o')
plt.grid(True)
plt.xlabel('D')
plt.ylabel('Error cuadratico')
plt.show()

# %%
np.sqrt(40)
# Out:
# 6.324555320336759

# %% [markdown]
# Podemos observar que tomando $\epsilon$ más chicos (entere 0.1 y 0.5nm) es donde se minimiza la distancia cuadratica, pero tambien es donde el tiempo de la simulación crece en forma exponencial (eso lo pedemos ver [acá](http://nbviewer.ipython.org/github/pewen/ten/blob/master/IPython_notebook/07_Profile_serial.ipynb#Variando-$\epsilon$-y-$D$)). Eso se debe a la relación entre los parámetros:
#
# \begin{equation}
# N = \dfrac{D}{\epsilon}
# \end{equation}

# %%
#Este css esta basado en el de @LorenaABarba y su grupo
from IPython.core.display import HTML
css_file = 'css/personal.css'
HTML(open(css_file, "r").read())
# Out:
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Arvo:400,700,400italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=PT+Mono' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Shadows+Into+Light' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Nixie+One' rel='stylesheet' type='text/css'>
# <style>
# @font-face {
#     font-family: "Computer Modern";
#     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
# #notebook_panel { /* main background */
#     background: rgb(245,245,245);
# }
# div.cell { /* set cell width */
#     width: 80%;
# }
# div #notebook { /* centre the content */
#     background: #fff; /* white background for content */
# ...

# %% [markdown]
# #####Licencia
#
# El código esta licenciado bajo MIT.
#
#
#
# La documentación bajo:
#
#
#
# <a rel="license" href="http://creativecommons.org/licenses/by/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by/4.0/88x31.png" /></a><br /><span xmlns:dct="http://purl.org/dc/terms/" property="dct:title">TEN</span> by <span xmlns:cc="http://creativecommons.org/ns#" property="cc:attributionName">Laboratorio de Microscopia Óptica Avanzada - UNRC</span> is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by/4.0/">Creative Commons Attribution 4.0 International License</a>.<br />Based on a work at <a xmlns:dct="http://purl.org/dc/terms/" href="https://github.com/pewen/ten" rel="dct:source">https://github.com/pewen/ten</a>
